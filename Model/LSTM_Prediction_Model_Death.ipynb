# %% [markdown]
# # Import the Libraries

# %%
import os
import pandas as pd #for Data analysis
import numpy as np  #for math purpose
import matplotlib.pyplot as plt # for visualize
import seaborn as sns
import plotly.express as px
from datetime import datetime, timedelta,date
import plotly.graph_objects as go
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.layers import Dropout
from matplotlib import pyplot
from keras import optimizers
from keras.optimizers import Adam
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_squared_error
from math import * 
from sklearn.metrics import r2_score

sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %% [markdown]
# # Import the Dataset

# %%
#url = 'https://drive.google.com/file/d/1urSCO_dPfMclcyMQuLCiNpxWCNeqyT1I/view?usp=sharing'
#path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
#df_germany = pd.read_csv(path)

# %%
df_germany = pd.read_csv(r'C:/Users/asifi/Documents/Lab_spatia_data/iteration2/kaggle/input/covid_de.csv')

# %%
nordrhein = df_germany.loc[df_germany['state'] == 'Nordrhein-Westfalen']
baden = df_germany.loc[df_germany['state'] == 'Baden-Wuerttemberg']
bayern = df_germany.loc[df_germany['state'] == 'Bayern']
berlin = df_germany.loc[df_germany['state'] == 'Berlin']
brandenburg = df_germany.loc[df_germany['state'] == 'Brandenburg']
bremen = df_germany.loc[df_germany['state'] == 'Bremen']
hamburg = df_germany.loc[df_germany['state'] == 'Hamburg']
hessen = df_germany.loc[df_germany['state'] == 'Hessen']
mecklenburg = df_germany.loc[df_germany['state'] == 'Mecklenburg-Vorpommern']
niedersachsen = df_germany.loc[df_germany['state'] == 'Niedersachsen']
rheinland= df_germany.loc[df_germany['state'] == 'Rheinland-Pfalz']
saarland = df_germany.loc[df_germany['state'] == 'Saarland']
sachsen = df_germany.loc[df_germany['state'] == 'Sachsen']
sachsen_anhalt = df_germany.loc[df_germany['state'] == 'Sachsen-Anhalt']
schleswig = df_germany.loc[df_germany['state'] == 'Schleswig-Holstein']
thueringen = df_germany.loc[df_germany['state'] == 'Thueringen']

# %% [markdown]
# # State

# %%
total = nordrhein.groupby(['date']).sum().reset_index()

# %%
total = total.set_index(pd.DatetimeIndex(total['date']))
total = total.drop(['date'], axis=1)

# %%
total['death_rate']=total.apply(lambda x: (x.deaths / x.cases)*100, axis = 1)
total['recovered_rate']=total.apply(lambda x: (x.recovered / x.cases)*100, axis = 1)
total.head(2)
# Out:
#             cases  deaths  recovered  death_rate  recovered_rate
# date
# 2020-01-02      3       0          3         0.0           100.0
# 2020-01-03      5       0          5         0.0           100.0

# %% [markdown]
# # Feature Engineering

# %%
from sklearn.preprocessing import MinMaxScaler
scaling  = MinMaxScaler()
total[['death_rate','recovered_rate']] = scaling.fit_transform(total[['death_rate','recovered_rate']])

# %%
plt.figure(figsize=(16,8))
plt.title('Death Rate in Nordrhein-Westfalen')
plt.plot(total['death_rate'], color='r')
plt.xlabel("Date", fontsize=18)
plt.ylabel('Death Rate (%)', fontsize=18)
plt.savefig('Death Rate in Nordrhein-Westfalen.png',dpi=50)
plt.show()

# %% [markdown]
# #### Remove Skewness

# %%
from scipy.stats import skew
total['death_rate']= np.sqrt(total['death_rate'])
skew(total['death_rate'])
# Out:
# 0.2739361928675075

# %%
plt.figure(figsize=(16,8))
plt.title('Death Rate in Nordrhein-Westfalen')
plt.plot(total['death_rate'], color='r')
plt.xlabel("Date", fontsize=18)
plt.ylabel('Death Rate (%)', fontsize=18)
plt.savefig('Death Rates in Nordrhein-Westfalen.png',dpi=50)
plt.show()

# %% [markdown]
# # Model

# %%
Data = total.filter(['death_rate'])
Data_Set = Data.values

#split the dataset into 75/25 for train and test.
Training_Data = int(np.ceil( len(Data_Set) * .75 ))

#scale the data 
SC = MinMaxScaler(feature_range=(0,1))
SC_Data  = SC.fit_transform(Data_Set)
#scaled_data

# %%
Training_Data
# Out:
# 243

# %%
Train_Data = SC_Data[0:Training_Data  , : ]

#splitting the data
Train_X =[]
Train_Y = []
Test_X = []
Test_Y =  Data_Set[Training_Data : , : ] 


for i in range(30, len(Train_Data)):
    Train_X.append(Train_Data[i-30:i,0])
    Train_Y.append(Train_Data[i,0])

# %%
Train_X, Train_Y = np.array(Train_X), np.array(Train_Y)

Train_X = np.reshape(Train_X, (Train_X.shape[0],Train_X.shape[1],1))

# %%
Test_Data = SC_Data[Training_Data - 30: , : ]

for i in range(30,len(Test_Data)):
    Test_X.append(Test_Data[i-30:i,0])
    
Test_X = np.array(Test_X)

Test_X = np.reshape(Test_X, (Test_X.shape[0],Test_X.shape[1],1))

# %%
model = Sequential()

model.add(LSTM(units = 128, return_sequences = True,  activation='relu',input_shape = (Train_X.shape[1], 1)))
model.add(LSTM(units = 64, return_sequences = True, activation='sigmoid'))
model.add(LSTM(units = 25, return_sequences = True, activation='sigmoid'))
model.add(LSTM(units = 5))
model.add(Dropout(0.2))
model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 128)           66560
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 64)            49408
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30, 25)            9000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 5)                 620
# _________________________________________________________________
# dropout (Dropout)            (None, 5)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 6
# =================================================================
# Total params: 125,594
# Trainable params: 125,594
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = optimizers.Adam(lr = 1e-4), metrics=['accuracy'], loss = 'mean_squared_error')

# %%
history = model.fit(Train_X, Train_Y, epochs=500, batch_size=5, validation_data=(Test_X, Test_Y))
# Out:
# Epoch 1/500
# 43/43 [==============================] - 7s 162ms/step - loss: 0.0936 - accuracy: 0.1268 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 2/500
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0796 - accuracy: 0.1268 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 3/500
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0741 - accuracy: 0.1362 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 4/500
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0701 - accuracy: 0.1362 - val_loss: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 5/500
# 43/43 [==============================] - 6s 144ms/step - loss: 0.0645 - accuracy: 0.1362 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 6/500
# 43/43 [==============================] - 6s 150ms/step - loss: 0.0561 - accuracy: 0.1362 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 7/500
# 43/43 [==============================] - 6s 147ms/step - loss: 0.0555 - accuracy: 0.1315 - val_loss: 0.0116 - val_accuracy: 0.0000e+00
# Epoch 8/500
# 43/43 [==============================] - 7s 158ms/step - loss: 0.0545 - accuracy: 0.1268 - val_loss: 0.0109 - val_accuracy: 0.0000e+00
# Epoch 9/500
# 43/43 [==============================] - 8s 179ms/step - loss: 0.0490 - accuracy: 0.1362 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 10/500
# 43/43 [==============================] - 8s 192ms/step - loss: 0.0475 - accuracy: 0.1408 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 11/500
# 43/43 [==============================] - 8s 177ms/step - loss: 0.0502 - accuracy: 0.1268 - val_loss: 0.0106 - val_accuracy: 0.0000e+00
# Epoch 12/500
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0468 - accuracy: 0.1362 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 13/500
# 43/43 [==============================] - 5s 124ms/step - loss: 0.0445 - accuracy: 0.1268 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 14/500
# 43/43 [==============================] - 7s 158ms/step - loss: 0.0412 - accuracy: 0.1362 - val_loss: 0.0105 - val_accuracy: 0.0000e+00
# Epoch 15/500
# 43/43 [==============================] - 8s 187ms/step - loss: 0.0430 - accuracy: 0.1315 - val_loss: 0.0195 - val_accuracy: 0.0000e+00
# Epoch 16/500
# 43/43 [==============================] - 7s 155ms/step - loss: 0.0439 - accuracy: 0.1315 - val_loss: 0.0153 - val_accuracy: 0.0000e+00
# Epoch 17/500
# 43/43 [==============================] - 6s 148ms/step - loss: 0.0437 - accuracy: 0.1268 - val_loss: 0.0118 - val_accuracy: 0.0000e+00
# Epoch 18/500
# 43/43 [==============================] - 6s 145ms/step - loss: 0.0405 - accuracy: 0.1315 - val_loss: 0.0155 - val_accuracy: 0.0000e+00
# Epoch 19/500
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0360 - accuracy: 0.1268 - val_loss: 0.0154 - val_accuracy: 0.0000e+00
# Epoch 20/500
# 43/43 [==============================] - 5s 122ms/step - loss: 0.0369 - accuracy: 0.1315 - val_loss: 0.0162 - val_accuracy: 0.0000e+00
# Epoch 21/500
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0354 - accuracy: 0.1408 - val_loss: 0.0221 - val_accuracy: 0.0000e+00
# Epoch 22/500
# 43/43 [==============================] - 5s 112ms/step - loss: 0.0368 - accuracy: 0.1315 - val_loss: 0.0170 - val_accuracy: 0.0000e+00
# Epoch 23/500
# 43/43 [==============================] - 5s 113ms/step - loss: 0.0345 - accuracy: 0.1362 - val_loss: 0.0138 - val_accuracy: 0.0000e+00
# Epoch 24/500
# 43/43 [==============================] - 5s 115ms/step - loss: 0.0372 - accuracy: 0.1362 - val_loss: 0.0130 - val_accuracy: 0.0000e+00
# Epoch 25/500
# 43/43 [==============================] - 5s 120ms/step - loss: 0.0356 - accuracy: 0.1362 - val_loss: 0.0154 - val_accuracy: 0.0000e+00
# Epoch 26/500
# 43/43 [==============================] - 5s 124ms/step - loss: 0.0378 - accuracy: 0.1174 - val_loss: 0.0173 - val_accuracy: 0.0000e+00
# Epoch 27/500
# 43/43 [==============================] - 6s 148ms/step - loss: 0.0434 - accuracy: 0.1268 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0260 - accuracy: 0.1408 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 107/500
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0309 - accuracy: 0.1408 - val_loss: 0.0175 - val_accuracy: 0.0000e+00
# Epoch 108/500
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0259 - accuracy: 0.1362 - val_loss: 0.0111 - val_accuracy: 0.0000e+00
# Epoch 109/500
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0294 - accuracy: 0.1315 - val_loss: 0.0134 - val_accuracy: 0.0000e+00
# Epoch 110/500
# 43/43 [==============================] - 5s 123ms/step - loss: 0.0309 - accuracy: 0.1408 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 111/500
# 43/43 [==============================] - 5s 122ms/step - loss: 0.0298 - accuracy: 0.1408 - val_loss: 0.0165 - val_accuracy: 0.0000e+00
# Epoch 112/500
# 43/43 [==============================] - 5s 115ms/step - loss: 0.0296 - accuracy: 0.1408 - val_loss: 0.0129 - val_accuracy: 0.0000e+00
# Epoch 113/500
# 43/43 [==============================] - 5s 117ms/step - loss: 0.0274 - accuracy: 0.1408 - val_loss: 0.0199 - val_accuracy: 0.0000e+00
# Epoch 114/500
# 43/43 [==============================] - 5s 115ms/step - loss: 0.0286 - accuracy: 0.1408 - val_loss: 0.0166 - val_accuracy: 0.0000e+00
# Epoch 115/500
# 43/43 [==============================] - 5s 115ms/step - loss: 0.0298 - accuracy: 0.1362 - val_loss: 0.0131 - val_accuracy: 0.0000e+00
# Epoch 116/500
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0286 - accuracy: 0.1362 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 117/500
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0265 - accuracy: 0.1408 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 118/500
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0290 - accuracy: 0.1362 - val_loss: 0.0131 - val_accuracy: 0.0000e+00
# Epoch 119/500
# 43/43 [==============================] - 5s 120ms/step - loss: 0.0252 - accuracy: 0.1408 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 120/500
# 43/43 [==============================] - 5s 122ms/step - loss: 0.0290 - accuracy: 0.1362 - val_loss: 0.0131 - val_accuracy: 0.0000e+00
# Epoch 121/500
# 43/43 [==============================] - 5s 121ms/step - loss: 0.0283 - accuracy: 0.1315 - val_loss: 0.0112 - val_accuracy: 0.0000e+00
# Epoch 122/500
# 43/43 [==============================] - 5s 123ms/step - loss: 0.0305 - accuracy: 0.1408 - val_loss: 0.0143 - val_accuracy: 0.0000e+00
# Epoch 123/500
# 43/43 [==============================] - 5s 124ms/step - loss: 0.0277 - accuracy: 0.1362 - val_loss: 0.0182 - val_accuracy: 0.0000e+00
# Epoch 124/500
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0291 - accuracy: 0.1408 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 125/500
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0296 - accuracy: 0.1408 - val_loss: 0.0129 - val_accuracy: 0.0000e+00
# Epoch 126/500
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0266 - accuracy: 0.1362 - val_loss: 0.0152 - val_accuracy: 0.0000e+00
# Epoch 127/500
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0260 - accuracy: 0.1408 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 128/500
# 43/43 [==============================] - 5s 124ms/step - loss: 0.0258 - accuracy: 0.1362 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 129/500
# 43/43 [==============================] - 5s 124ms/step - loss: 0.0285 - accuracy: 0.1408 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 130/500
# 43/43 [==============================] - 5s 121ms/step - loss: 0.0290 - accuracy: 0.1362 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 131/500
# 43/43 [==============================] - 5s 123ms/step - loss: 0.0300 - accuracy: 0.1408 - val_loss: 0.0109 - val_accuracy: 0.0000e+00
# Epoch 132/500
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0297 - accuracy: 0.1408 - val_loss: 0.0174 - val_accuracy: 0.0000e+00
# Epoch 133/500
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0271 - accuracy: 0.1408 - val_loss: 0.0121 - val_accuracy: 0.0000e+00
# Epoch 134/500
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0295 - accuracy: 0.1362 - val_loss: 0.0124 - val_accuracy: 0.0000e+00
# Epoch 135/500
# 43/43 [==============================] - 5s 125ms/step - loss: 0.
- val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 480/500
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0236 - accuracy: 0.1408 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 481/500
# 43/43 [==============================] - 5s 123ms/step - loss: 0.0248 - accuracy: 0.1362 - val_loss: 0.0124 - val_accuracy: 0.0000e+00
# Epoch 482/500
# 43/43 [==============================] - 5s 109ms/step - loss: 0.0233 - accuracy: 0.1408 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 483/500
# 43/43 [==============================] - 5s 115ms/step - loss: 0.0239 - accuracy: 0.1408 - val_loss: 0.0117 - val_accuracy: 0.0000e+00
# Epoch 484/500
# 43/43 [==============================] - 5s 114ms/step - loss: 0.0228 - accuracy: 0.1408 - val_loss: 0.0128 - val_accuracy: 0.0000e+00
# Epoch 485/500
# 43/43 [==============================] - 5s 115ms/step - loss: 0.0239 - accuracy: 0.1408 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 486/500
# 43/43 [==============================] - 5s 112ms/step - loss: 0.0237 - accuracy: 0.1408 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 487/500
# 43/43 [==============================] - 6s 142ms/step - loss: 0.0227 - accuracy: 0.1408 - val_loss: 0.0155 - val_accuracy: 0.0000e+00
# Epoch 488/500
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0221 - accuracy: 0.1408 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 489/500
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0240 - accuracy: 0.1408 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 490/500
# 43/43 [==============================] - 6s 139ms/step - loss: 0.0244 - accuracy: 0.1408 - val_loss: 0.0161 - val_accuracy: 0.0000e+00
# Epoch 491/500
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0242 - accuracy: 0.1408 - val_loss: 0.0128 - val_accuracy: 0.0000e+00
# Epoch 492/500
# 43/43 [==============================] - 6s 139ms/step - loss: 0.0228 - accuracy: 0.1408 - val_loss: 0.0106 - val_accuracy: 0.0000e+00
# Epoch 493/500
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0241 - accuracy: 0.1408 - val_loss: 0.0157 - val_accuracy: 0.0000e+00
# Epoch 494/500
# 43/43 [==============================] - 6s 137ms/step - loss: 0.0238 - accuracy: 0.1408 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 495/500
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0236 - accuracy: 0.1408 - val_loss: 0.0099 - val_accuracy: 0.0000e+00
# Epoch 496/500
# 43/43 [==============================] - 5s 120ms/step - loss: 0.0239 - accuracy: 0.1408 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 497/500
# 43/43 [==============================] - 5s 120ms/step - loss: 0.0240 - accuracy: 0.1408 - val_loss: 0.0105 - val_accuracy: 0.0000e+00
# Epoch 498/500
# 43/43 [==============================] - 5s 118ms/step - loss: 0.0238 - accuracy: 0.1408 - val_loss: 0.0135 - val_accuracy: 0.0000e+00
# Epoch 499/500
# 43/43 [==============================] - 5s 121ms/step - loss: 0.0234 - accuracy: 0.1408 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 500/500
# 43/43 [==============================] - 6s 141ms/step - loss: 0.0253 - accuracy: 0.1408 - val_loss: 0.0098 - val_accuracy: 0.0000e+00

# %%
predictions = model.predict(Test_X) 
predictions = SC.inverse_transform(predictions)

# %%
train = Data[:Training_Data]
validation = Data[Training_Data:]
validation['Predictions'] = predictions
# Out:
# C:\Users\asifi\anaconda3\envs\cmdpython37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(16,8))
plt.title('Nordrhein-Westfalen LSTM Model Death Rate Prediction')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Death Rate (%)', fontsize=18)
plt.plot(train['death_rate'])
plt.plot(validation[['death_rate', 'Predictions']])
plt.legend(['Train', 'Test', 'Predictions'], loc='upper right')
plt.savefig('Nordrhein-WestfalenLSTM Model Death Rate Prediction.png',dpi=50)
plt.show()

# %%
validation
# Out:
#             death_rate  Predictions
# date
# 2020-10-17    0.363879     0.235882
# 2020-10-18    0.359974     0.238085
# 2020-10-19    0.375085     0.242421
# 2020-10-20    0.372012     0.246525
# 2020-10-21    0.338145     0.252864
# ...                ...          ...
# 2020-12-31    0.188303     0.353459
# 2021-01-01    0.189406     0.328022
# 2021-01-02    0.128254     0.305252
# 2021-01-03    0.183214     0.286033
# 2021-01-04    0.230490     0.270800
#
# [80 rows x 2 columns]

# %% [markdown]
# # Model Evaluation

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('LSTM Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.savefig('Nordrhein-Westfalen LSTM Model Loss.png',dpi=100)
plt.show()

# %%
Probs_Y = model.predict(Test_X)
Class_Y = model.predict_classes(Test_X)

Probs_Y = Probs_Y[:, 0]
Class_Y = Class_Y[:, 0]
# Out:
# WARNING:tensorflow:From <ipython-input-25-4bd0630d6226>:2: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %% [markdown]
# ### Mean Squared Error

# %%
MSE  = mean_squared_error(Test_Y,Probs_Y)
print('Mean Squared Error: %f' % MSE)
# Out:
# Mean Squared Error: 0.009829

# %% [markdown]
# ### Root Mean Squared Error

# %%
RMSE = sqrt(MSE)
print('Root Mean Squared Error: %f' % RMSE)
# Out:
# Root Mean Squared Error: 0.099143

# %% [markdown]
# ### Accuracy

# %%
accuracy = accuracy_score(Test_Y.round(), Class_Y)
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.800000

# %% [markdown]
# ### R^2 score

# %%
r = r2_score(Test_Y,Probs_Y)
print('Score: %f' % r)
# Out:
# Score: -0.365305

# %% [markdown]
# ###  Area Under the Receiver Operating Characteristic Curve Score

# %%
auc = roc_auc_score(Test_Y.round(), Probs_Y)
print('ROC AUC: %f' % auc)
# Out:
# ROC AUC: 0.756757

# %% [markdown]
# ### Confusion matrix

# %%
matrix = confusion_matrix(Test_Y.round(), Class_Y)
print(matrix)
# Out:
# [[63 11]
#  [ 5  1]]

# %% [markdown]
# ### Precision

# %%
precision = precision_score(Test_Y.round(), Class_Y)
print('Precision: %f' % precision)
# Out:
# Precision: 0.083333

# %% [markdown]
# ### Recall

# %%
recall = recall_score(Test_Y.round(), Class_Y)
print('Recall: %f' % recall)
# Out:
# Recall: 0.166667

# %% [markdown]
# ### F1 Score

# %%
f1 = f1_score(Test_Y.round(), Class_Y)
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.111111
